# %%
# !pip install cloudscraper
# Out:
# Collecting cloudscraper
#   Downloading cloudscraper-1.2.71-py2.py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: pyparsing>=2.4.7 in /usr/local/lib/python3.11/dist-packages (from cloudscraper) (3.2.3)
# Requirement already satisfied: requests>=2.9.2 in /usr/local/lib/python3.11/dist-packages (from cloudscraper) (2.32.3)
# Requirement already satisfied: requests-toolbelt>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from cloudscraper) (1.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.9.2->cloudscraper) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.9.2->cloudscraper) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.9.2->cloudscraper) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.9.2->cloudscraper) (2025.4.26)
# Downloading cloudscraper-1.2.71-py2.py3-none-any.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.7/99.7 kB 2.0 MB/s eta 0:00:00
# Installing collected packages: cloudscraper
# Successfully installed cloudscraper-1.2.71

# %%
import pyspark
from pyspark.sql import SparkSession


spark = SparkSession.builder.appName("HelloWorld").getOrCreate()
sc = spark.sparkContext

nums = sc.parallelize([1,2,3,4])
result=nums.map(lambda x: x*x).collect()
print(result)
# Out:
# [1, 4, 9, 16]

# %%
import pandas as pd
import cloudscraper
from bs4 import BeautifulSoup

def scrape_reviews_to_df(perfume_urls):
    scraper = cloudscraper.create_scraper(
        browser={
            'browser': 'chrome',
            'platform': 'windows',
            'mobile': False
        }
    )
    all_reviews = []

    for perfume_url in perfume_urls:
        reviews = []
        page_url = perfume_url

        while page_url:
            resp = scraper.get(page_url)
            resp.raise_for_status()
            soup = BeautifulSoup(resp.text, 'html.parser')

            for box in soup.select('div.fragrance-review-box'):
                author_el = box.select_one('[itemprop="author"] [itemprop="name"]')
                date_el   = box.select_one('[itemprop="datePublished"]')
                perf_el   = box.select_one('.perfume-wearing-icon')
                rate_el   = box.select_one('[rating-vote]')
                text_el   = box.select_one('[itemprop="reviewBody"]')

                reviews.append({
                    'url': perfume_url,
                    'author':      author_el  ['content'] if author_el else None,
                    'date':        date_el    ['content'] if date_el   else None,
                    'perfume':     perf_el    ['title']   if perf_el   else None,
                    'rating':      int(rate_el['rating-vote']) if rate_el else None,
                    'review_text': text_el.get_text(strip=True)   if text_el  else None
                })

            next_link = soup.select_one('ul.pagination li.next a')
            page_url = ('https://www.fragrantica.com.br' + next_link['href']) if next_link else None

        all_reviews.extend(reviews)

    return pd.DataFrame(all_reviews)

if __name__ == '__main__':
    urls = [
        'https://www.fragrantica.com.br/perfume/Carolina-Herrera/Good-Girl-39681.html',
        'https://www.fragrantica.com.br/perfume/Lancome/La-Vie-Est-Belle-14982.html',
        'https://www.fragrantica.com.br/perfume/Yves-Saint-Laurent/Libre-56077.html',
        'https://www.fragrantica.com.br/perfume/Prada/Prada-Paradoxe-75668.html',
        'https://www.fragrantica.com.br/perfume/Jean-Paul-Gaultier/Scandal-45651.html',
        'https://www.fragrantica.com.br/perfume/Giorgio-Armani/My-Way-62036.html',
        'https://www.fragrantica.com.br/perfume/Dior/J-Adore-L-Or-10371.html',
        'https://www.fragrantica.com.br/perfume/Giorgio-Armani/Si-18453.html',
        'https://www.fragrantica.com.br/perfume/Yves-Saint-Laurent/Black-Opium-Eau-de-Toilette-31440.html',
        'https://www.fragrantica.com.br/perfume/Chanel/Coco-Mademoiselle-611.html',
        'https://www.fragrantica.com.br/perfume/Lancome/Idole-55795.html',
        'https://www.fragrantica.com.br/perfume/Dior/Miss-Dior-Eau-de-Parfum-2021-68905.html',
        'https://www.fragrantica.com.br/perfume/Calvin-Klein/Euphoria-253.html',
        'https://www.fragrantica.com.br/perfume/Givenchy/L-Interdit-Eau-de-Parfum-51488.html'

        # Add more URLs as needed
    ]
    df = scrape_reviews_to_df(urls)
    print(df)
# Out:
#                                                     url  \
# 0     https://www.fragrantica.com.br/perfume/Carolin...
# 1     https://www.fragrantica.com.br/perfume/Carolin...
# 2     https://www.fragrantica.com.br/perfume/Carolin...
# 3     https://www.fragrantica.com.br/perfume/Carolin...
# 4     https://www.fragrantica.com.br/perfume/Carolin...
# ...                                                 ...
# 2456  https://www.fragrantica.com.br/perfume/Givench...
# 2457  https://www.fragrantica.com.br/perfume/Givench...
# 2458  https://www.fragrantica.com.br/perfume/Givench...
# 2459  https://www.fragrantica.com.br/perfume/Givench...
# 2460  https://www.fragrantica.com.br/perfume/Givench...
#
#                      author        date                               perfume  \
# 0                  Sylvinha  2025-06-06  Valentino Donna Born In Roma Intense
# 1                    Mah C.  2025-06-01                                  None
# 2                bbrendinha  2025-05-30              All or Nothing Amplified
# 3             VictoriaBarch  2025-05-20                                  None
# 4               Ana Montano  2025-05-18                                  None
# ...                     ...         ...                                   ...
# 2456            Buh Martins  2022-07-26                                Sirène
# 2457                 AlineC  2021-09-07                             Magdalene
# 2458  Naty_sinfoniaagridoce  2019-01-24                            Uva Merlot
# 2459            liiyamasaki  2022-08-30                                  None
# 2460         Brendalcantara  2018-10-05                       Delina La Rosée
#
#      rating                                        review_text
# 0      None  Demorei pra conhecer esse perfume porque eu ti...
# 1      None  Marcante, doce na medida certa, secreto e inte...
# 2      None  No meio dos colecionadores parece que virou “c...
# 3      None  Acho que ele tem um cheiro muito forte, ataca ...
# 4      None  Para mim ele é doce e cansativo. Não o conside...
# ...     ...                                                ...
# 2456   None  Hoje, vi uma famosa executiva  de perfumaria, ...
# 2457   None  Nunca um perfume me enjoou tanto na vida. Comp...
# 2458   None  Saída explosiva e chicletosa com bastante flor...
# 2459   None  Me interessei pelo l'interdit após o hype dele...
# 2460   None  Que perfume delicioso, quando borrifa vc fica ...
#
# [2461 rows x 6 columns]

# %%
import cloudscraper
from bs4 import BeautifulSoup

# 1) Fetch the “female 2023” search page
search_url = "https://www.fragrantica.com.br/busca/?godina=2023%3A&spol=female"
scraper = cloudscraper.create_scraper(
    browser={"browser": "chrome", "platform": "windows", "mobile": False}
)
resp = scraper.get(search_url)
resp.raise_for_status()
soup = BeautifulSoup(resp.text, "html.parser")

# %%
perfumes = []
for card in soup.select("div.fr-news-box"):
    # Only select <a> tags whose href begins with "/perfume/"
    a_tag = card.select_one('a[href^="/perfume/"]')
    if not a_tag:
        continue

    href = a_tag["href"]  # e.g. "/perfume/Burberry/Goddess-83483.html"
    if not href.startswith("/perfume/"):
        continue  # skip anything that isn’t a proper perfume link

    full_url = "https://www.fragrantica.com.br" + href
    name = a_tag.get_text(strip=True)

    perfumes.append((name, full_url))
perfumes
# Out:
# [('Azzaro Orange Tonic',
#   'https://www.fragrantica.com.br/perfume/Azzaro/Orange-Tonic-1.html'),
#  ('Givenchy Amarige',
#   'https://www.fragrantica.com.br/perfume/Givenchy/Amarige-3.html'),
#  ('Givenchy Organza',
#   'https://www.fragrantica.com.br/perfume/Givenchy/Organza-4.html'),
#  ("Dior J'adore Eau de Toilette 2002",
#   'https://www.fragrantica.com.br/perfume/Dior/J-adore-Eau-de-Toilette-2002-5.html'),
#  ('Lanvin Arpège',
#   'https://www.fragrantica.com.br/perfume/Lanvin/Arpege-6.html'),
#  ('Hermès Equipage',
#   'https://www.fragrantica.com.br/perfume/Hermes/Equipage-7.html'),
#  ('Hermès Rouge Hermes Eau Delicate',
#   'https://www.fragrantica.com.br/perfume/Hermes/Rouge-Hermes-Eau-Delicate-8.html'),
#  ('Hermès Eau des Merveilles',
#   'https://www.fragrantica.com.br/perfume/Hermes/Eau-des-Merveilles-9.html'),
#  ('Hermès Parfum des Merveilles',
#   'https://www.fragrantica.com.br/perfume/Hermes/Parfum-des-Merveilles-10.html'),
#  ('Chanel Chanel N°19',
#   'https://www.fragrantica.com.br/perfume/Chanel/Chanel-N019-11.html'),
#  ('Chanel Cristalle Eau de Toilette',
#   'https://www.fragrantica.com.br/perfume/Chanel/Cristalle-Eau-de-Toilette-12.html'),
#  ("Guerlain Apres l'Ondee",
#   'https://www.fragrantica.com.br/perfume/Guerlain/Apres-l-Ondee-13.html'),
#  ('Lanvin Arpege Pour Homme',
#   'https://www.fragrantica.com.br/perfume/Lanvin/Arpege-Pour-Homme-14.html'),
#  ('Robert Piguet Bandit',
#   'https://www.fragrantica.com.br/perfume/Robert-Piguet/Bandit-15.html'),
#  ('Guerlain Habit Rouge Eau de Toilette',
#   'https://www.fragrantica.com.br/perfume/Guerlain/Habit-Rouge-Eau-de-Toilette-16.html'),
#  ("Hermès Terre d'Hermès",
#   'https://www.fragrantica.com.br/perfume/Hermes/Terre-d-Hermes-17.html'),
#  ('Hermès Un Jardin Sur Le Nil',
#   'https://www.fragrantica.com.br/perfume/Hermes/Un-Jardin-Sur-Le-Nil-18.html'),
#  ('Hermès Un Jardin en Méditerranée',
#   'https://www.fragrantica.com.br/perfume/Hermes/Un-Jardin-en-Mediterranee-19.html'),
#  ('Hermès Hiris',
#   'https://www.fragrantica.com.br/perfume/Hermes/Hiris-20.html'),
#  ('Hermès Rouge Hermès',
#   'https://www.fragrantica.com.br/perfume/Hermes/Rouge-Hermes-21.html'),
#  ('Hermès 24 Faubourg Eau Delicate',
#   'https://www.fragrantica.com.br/perfume/Hermes/24-Faubourg-Eau-Delicate-22.html'),
#  ('Hermès Caleche',
#   'https://www.fragrantica.com.br/perfume/Hermes/Caleche-23.html'),
#  ('Hermès Caleche Eau Delicate',
#   'https://www.fragrantica.com.br/perfume/Hermes/Caleche-Eau-Delicate-24.html'),
#  ('Hermès Bel Ami',
#   'https://www.fragrantica.com.br/perfume/Hermes/Bel-Ami-25.html'),
#  ('Hermès Rocabar',
#   'https://www.fragrantica.com.br/perfume/Hermes/Rocabar-26.html'),
#  ('Hermès 24 Faubourg',
#   'https://www.fragrantica.com.br/perfume/Hermes/24-Faubourg-27.html'),
#  ('Rochas Femme Rochas',
#   'https://www.fragrantica.com.br/perfume/Rochas/Femme-Rochas-28.html'),
#  ('Caron Tabac Blond',
#   'https://www.fragrantica.com.br/perfume/Caron/Tabac-Blond-29.html'),
#  ('Azzaro Visit for Women',
#   'https://www.fragrantica.com.br/perfume/Azzaro/Visit-for-Women-30.html'),
#  ('Angel Schlesser Angel Schlesser Femme',
#   'https://www.fragrantica.com.br/perfume/Angel-Schlesser/Angel-Schlesser-Femme-31.html'),
#  ('Angel Schlesser Angel Schlesser Essential',
#   'https://www.fragrantica.com.br/perfume/Angel-Schlesser/Angel-Schlesser-Essential-32.html'),
#  ('Givenchy Very Irresistible',
#   'https://www.fragrantica.com.br/perfume/Givenchy/Very-Irresistible-33.html'),
#  ('Givenchy Very Irresistible for men',
#   'https://www.fragrantica.com.br/perfume/Givenchy/Very-Irresistible-for-men-34.html'),
#  ('Givenchy Hot Couture',
#   'https://www.fragrantica.com.br/perfume/Givenchy/Hot-Couture-35.html'),
#  ('Givenchy Ysatis',
#   'https://www.fragrantica.com.br/perfume/Givenchy/Ysatis-36.html'),
#  ('Givenchy Givenchy pour Homme',
#   'https://www.fragrantica.com.br/perfume/Givenchy/

#   'https://www.fragrantica.com.br/perfume/Kenzo/Kenzo-Jungle-Homme-71.html'),
#  ('Kenzo Flower by Kenzo',
#   'https://www.fragrantica.com.br/perfume/Kenzo/Flower-by-Kenzo-72.html'),
#  ('Kenzo Flower by Kenzo Le Parfum',
#   'https://www.fragrantica.com.br/perfume/Kenzo/Flower-by-Kenzo-Le-Parfum-73.html'),
#  ('Kenzo Flower by Kenzo Oriental',
#   'https://www.fragrantica.com.br/perfume/Kenzo/Flower-by-Kenzo-Oriental-74.html'),
#  ('Kenzo Air', 'https://www.fragrantica.com.br/perfume/Kenzo/Air-75.html'),
#  ('Kenzo Summer by Kenzo',
#   'https://www.fragrantica.com.br/perfume/Kenzo/Summer-by-Kenzo-76.html'),
#  ('Kenzo Kenzo pour Homme',
#   'https://www.fragrantica.com.br/perfume/Kenzo/Kenzo-pour-Homme-77.html'),
#  ("Kenzo L'Eau par Kenzo",
#   'https://www.fragrantica.com.br/perfume/Kenzo/L-Eau-par-Kenzo-78.html'),
#  ("Kenzo L'Eau par Kenzo pour Homme",
#   'https://www.fragrantica.com.br/perfume/Kenzo/L-Eau-par-Kenzo-pour-Homme-79.html'),
#  ("Kenzo Parfum d'Ete 2002",
#   'https://www.fragrantica.com.br/perfume/Kenzo/Parfum-d-Ete-2002-80.html'),
#  ('Elizabeth Arden 5th Avenue',
#   'https://www.fragrantica.com.br/perfume/Elizabeth-Arden/5th-Avenue-81.html'),
#  ('Elizabeth Arden 5th Avenue After Five',
#   'https://www.fragrantica.com.br/perfume/Elizabeth-Arden/5th-Avenue-After-Five-82.html'),
#  ('Elizabeth Arden Green Tea',
#   'https://www.fragrantica.com.br/perfume/Elizabeth-Arden/Green-Tea-83.html'),
#  ('Elizabeth Arden Provocative Woman',
#   'https://www.fragrantica.com.br/perfume/Elizabeth-Arden/Provocative-Woman-84.html'),
#  ('Elizabeth Arden Provocative Interlude',
#   'https://www.fragrantica.com.br/perfume/Elizabeth-Arden/Provocative-Interlude-85.html'),
#  ('Elizabeth Arden Red Door',
#   'https://www.fragrantica.com.br/perfume/Elizabeth-Arden/Red-Door-86.html'),
#  ('Elizabeth Arden Red Door Revealed',
#   'https://www.fragrantica.com.br/perfume/Elizabeth-Arden/Red-Door-Revealed-87.html'),
#  ('Elizabeth Arden Arden Beauty',
#   'https://www.fragrantica.com.br/perfume/Elizabeth-Arden/Arden-Beauty-88.html'),
#  ('Elizabeth Arden Splendor',
#   'https://www.fragrantica.com.br/perfume/Elizabeth-Arden/Splendor-89.html'),
#  ('Elizabeth Arden Eau Fraiche',
#   'https://www.fragrantica.com.br/perfume/Elizabeth-Arden/Eau-Fraiche-90.html'),
#  ('Elizabeth Arden Blue Grass',
#   'https://www.fragrantica.com.br/perfume/Elizabeth-Arden/Blue-Grass-91.html'),
#  ('Yves Saint Laurent Cinéma',
#   'https://www.fragrantica.com.br/perfume/Yves-Saint-Laurent/Cinema-92.html'),
#  ('Yves Saint Laurent Opium (1977)',
#   'https://www.fragrantica.com.br/perfume/Yves-Saint-Laurent/Opium-1977-93.html'),
#  ('Yves Saint Laurent Paris',
#   'https://www.fragrantica.com.br/perfume/Yves-Saint-Laurent/Paris-94.html'),
#  ('Yves Saint Laurent Nu',
#   'https://www.fragrantica.com.br/perfume/Yves-Saint-Laurent/Nu-95.html'),
#  ('Yves Saint Laurent Rive Gauche',
#   'https://www.fragrantica.com.br/perfume/Yves-Saint-Laurent/Rive-Gauche-96.html'),
#  ('Gucci Envy', 'https://www.fragrantica.com.br/perfume/Gucci/Envy-97.html'),
#  ('Chanel Les Exclusifs de Chanel Cuir de Russie 1924',
#   'https://www.fragrantica.com.br/perfume/Chanel/Les-Exclusifs-de-Chanel-Cuir-de-Russie-1924-98.html'),
#  ('Yves Saint Laurent Baby Doll',
#   'https://www.fragrantica.com.br/perfume/Yves-Saint-Laurent/Baby-Doll-99.html'),
#  ('Yves Saint Laurent Y',
#   'https://www.fragrantica.com.br/perfume/Yves-Saint-Laurent/Y-100.html'),
#  ('Yves Saint Laurent Yvresse (Champagne)',
#   'https://www.fragrantica.com.br/perfume/Yves-Saint-Laurent/Yvresse-Champagne-101.html'),
#  ("L'Artisan Parfumeur Mandarine Tout Simplement",
#   'https://www.fragrantica.com.br/perfume/L-Artisan-Parfumeur/Mandarine-Tout-Simplement-102.html'),
#  ('Guerlain Jicky',
#   'https://www.fragrantica.com.br/perfume/Guerlain/Jicky-103.html'),
#  ('Yves Saint Laurent In Love Again',
#   'https://www.fragrantica.com.br/perfume/Yves-Saint-Laurent/In-Love-Again-104.html'),
#  ('Annayake Annayake Pour Elle',
#   'https://www.fragrantica.com.br/perfume/Annayake/Annayake-Pour-Elle-105.html'),
#  ('Annayake Annayake Pour Lui',
#   'https://www.fragrantica.com.br/perfume/Annayake/Annayake-Pour-Lui-106.html'),
#  ('Annayake Hanami',
#   'https://www.fragrantica.com.br/perfume/Annayake/Hanami-107.html'),
#  ('Annayake Natsumi',
#   'https://www.fragrantica.com.br/perfume/Annayake/Natsumi-108.html'),
#  ('Annayake Tsukimi',
#   'https://www.fragrantica.com.br/perfume/Annayake/Tsukimi-109.html'),
#  ('Annayake Undo pour Homme',
#   'https://www.fragrantica.com.br/perfume/Annayake/Undo-pour-Homme-110.html'),
#  ('Annayake Yukimi',
#   'https://www.fragrantica.com.br/perfume/Annayake/Yukimi-111.html'),
#  ('Antonio Banderas Diavolo',
#   'https://www.fragrantica.com.br/perfume/Antonio-Banderas/Diavolo-112.html'),
#  ('Aramis Aramis',
#   'https://www.fragrantica.com.br/perfume/Aramis/Aramis-113.html'),
#  ('Aramis Aramis Always for Her',
#   'https://www.fragrantica.com.br/perfume/Aramis/Aramis-Always-for-Her-114.html'),
#  ('Aramis Aramis Always for Him',
#   'https://www.fragrantica.com.br/perfume/Aramis/Aramis-Always-for-Him-115.html'),
#  ('Aramis Aramis 900',
#   'https://www.fragrantica.com.br/perfume/Aramis/Aramis-900-116.html'),
#  ('Aramis Aramis Bermuda Tonic',
#   'https://www.fragrantica.com.br/perfume/Aramis/Aramis-Bermuda-Tonic-117.html'),
#  ('Aramis Aramis Cool',
#   'https://www.fragrantica.com.br/perfume/Aramis/Aramis-Cool-118.html'),
#  ('Aramis Aramis Ice',
#   'https://www.fragrantica.com.br/perfume/Aramis/Aramis-Ice-119.html'),
#  ('Aramis Aramis Life',
#   'https://www.fragrantica.com.br/perfume/Aramis/Aramis-Life-120.html'),
#  ('Aramis Aramis Life My Summer',
#   'https://www.fragrantica.com.br/perfume/Aramis/Aramis-Life-My-Summer-121.html'),
#  ('Aramis Tuscany Per Donna',
#   'https://www.fragrantica.com.br/perfume/Aramis/Tuscany-Per-Donna-122.html'),
#  ('Aramis Tuscany Per Uomo',
#   'https://www.fragrantica.com.br/perfume/Aramis/Tuscany-Per-Uomo-123.html'),
#  ('Armand Basi Basi Femme',
#   'https://www.fragrantica.com.br/perfume/Armand-Basi/Basi-Femme-124.html'),
#  ('Armand Basi Armand Basi Homme',
#   'https://www.fragrantica.com.br/perfume/Armand-Basi/Armand-Basi-Homme-125.html'),
#  ('Armand Basi Basi Homme',
#   'https://www.fragrantica.com.br/perfume/Armand-Basi/Basi-Homme-126.html'),
#  ('Armand Basi In Blue',
#   'https://www.fragrantica.com.br/perfume/Armand-Basi/In-Blue-127.html'),
#  ('Armand Basi In Red',
#   'https://www.fragrantica.com.br/perfume/Armand-Basi/In-Red-128.html'),
#  ('Banana Republic Banana Republic W',
#   'https://www.fragrantica.com.br/perfume/Banana-Republic/Banana-Republic-W-129.html'),
#  ('Bill Blass Nude',
#   'https://www.fragrantica.com.br/perfume/Bill-Blass/Nude-130.html'),
#  ('Byblos Byblos',
#   'https://www.fragrantica.com.br/perfume/Byblos/Byblos-131.html'),
#  ('Boucheron Boucheron Pour Homme',
#   'https://www.fragrantica.com.br/perfume/Boucheron/Boucheron-Pour-Homme-132.html'),
#  ('Boucheron Boucheron',
#   'https://www.fragrantica.com.br/perfume/Boucheron/Boucheron-133.html'),
#  ('Boucheron Initial',
#   'https://www.fragrantica.com.br/perfume/Boucheron/Initial-134.html'),
#  ('Boucheron Trouble',
#   'https://www.fragrantica.com.br/perfume/Boucheron/Trouble-135.html'),
#  ('Boucheron Jaipur',
#   'https://www.fragrantica.com.br/perfume/Boucheron/Jaipur-136.html'),
#  ('Boucheron Jaipur Homme',
#   'https://www.fragrantica.com.br/perfume/Boucheron/Jaipur-Homme-137.html'),
#  ('Boucheron Jaipur Saphir',
#   'https://www.fragrantica.com.br/perfume/Boucheron/Jaipur-Saphir-138.html'),
#  ('Blumarine Blumarine II',
#   'https://www.fragrantica.com.br/perfume/Blumarine/Blumarine-II-139.html'),
#  ('Blumarine Vintage',
#   'https://www.fragrantica.com.br/perfume/Blumarine/Vintage-140.html'),
#  ('Britney Spears Curious',
#   'https://www.fragrantica.com.br/perfume/Britney-Spears/Curious-141.html'),
#  ('Bvlgari Bvlgari Pour Femme',
#   'https://www.fragrantica.com.br/perfume/Bvlgari/Bvlgari-Pour-Femme-142.html'),
#  ('Bvlgari Bvlgari Pour Homme',
#   'https://www.fragrantica.com.br/perfume/Bvlgari/Bvlgari-Pour-Homme-143.html'),
#  ('Bvlgari Eau Parfumee au The Vert',
#   'https://www.fragrantica.com.br/perfume/Bvlgari/Eau-Parfumee-au-The-Vert-144.html'),
#  ('Bvlgari Eau Parfumee au The Blanc',
#   'https://www.fragrantica.com.br/perfume/Bvlgari/Eau-Parfumee-au-The-Blanc-145.html'),
#  ('Bvlgari Eau Parfumee au The Rouge',
#   'https://www.fragrantica.com.br/perfume/Bvlgari/Eau-Parfumee-au-The-Rouge-146.html'),
#  ('Nina Ricci Nina',
#   'https://www.fragrantica.com.br/perfume/Nina-Ricci/Nina-147.html'),
#  ('Bvlgari BLV Pour Homme',
#   'https://www.fragrantica.com.br/perfume/Bvlgari/BLV-Pour-Homme-148.html'),
#  ('Bvlgari BLV Notte Pour Femme',
#   'https://www.fragrantica.com.br/perfume/Bvlgari/BLV-Notte-Pour-Femme-149.html'),
#  ('Bvlgari BLV Notte Pour Homme',
#   'https://www.fragrantica.com.br/perfume/Bvlgari/BLV-Notte-Pour-Homme-150.html'),
#  ('Bvlgari Omnia',
#   'https://www.fragrantica.com.br/perfume/Bvlgari/Omnia-151.html')]

# %%
def scrape_reviews_to_df(perfume_urls):
    scraper = cloudscraper.create_scraper(
        browser={
            'browser': 'chrome',
            'platform': 'windows',
            'mobile': False
        }
    )
    all_reviews = []

    for perfume_url in perfume_urls:
        reviews = []
        page_url = perfume_url

        while page_url:
            resp = scraper.get(page_url)
            resp.raise_for_status()
            soup = BeautifulSoup(resp.text, 'html.parser')

            for box in soup.select('div.fragrance-review-box'):
                author_el = box.select_one('[itemprop="author"] [itemprop="name"]')
                date_el   = box.select_one('[itemprop="datePublished"]')
                perf_el   = box.select_one('.perfume-wearing-icon')
                rate_el   = box.select_one('[rating-vote]')
                text_el   = box.select_one('[itemprop="reviewBody"]')

                reviews.append({
                    'url': perfume_url,
                    'author':      author_el  ['content'] if author_el else None,
                    'date':        date_el    ['content'] if date_el   else None,
                    'perfume':     perf_el    ['title']   if perf_el   else None,
                    'rating':      int(rate_el['rating-vote']) if rate_el else None,
                    'review_text': text_el.get_text(strip=True)   if text_el  else None
                })

            next_link = soup.select_one('ul.pagination li.next a')
            page_url = ('https://www.fragrantica.com.br' + next_link['href']) if next_link else None

        all_reviews.extend(reviews)

    return pd.DataFrame(all_reviews)

# %%
all_reviews_df = pd.DataFrame()

for (perfume_name, perfume_url) in perfumes:
    print(f"\n=== Scraping reviews for: {perfume_name} ===")
    df_reviews = scrape_reviews_to_df([perfume_url])
    all_reviews_df = pd.concat([all_reviews_df, df_reviews], ignore_index=True)

print(all_reviews_df.head())
# Out:
# === Scraping reviews for: Azzaro Orange Tonic ===
#
# === Scraping reviews for: Givenchy Amarige ===
#
# === Scraping reviews for: Givenchy Organza ===
#
# === Scraping reviews for: Dior J'adore Eau de Toilette 2002 ===
#
# === Scraping reviews for: Lanvin Arpège ===
#
# === Scraping reviews for: Hermès Equipage ===
#
# === Scraping reviews for: Hermès Rouge Hermes Eau Delicate ===
#
# === Scraping reviews for: Hermès Eau des Merveilles ===
#
# === Scraping reviews for: Hermès Parfum des Merveilles ===
#
# === Scraping reviews for: Chanel Chanel N°19 ===
#
# === Scraping reviews for: Chanel Cristalle Eau de Toilette ===
#
# === Scraping reviews for: Guerlain Apres l'Ondee ===
#
# === Scraping reviews for: Lanvin Arpege Pour Homme ===
#
# === Scraping reviews for: Robert Piguet Bandit ===
#
# === Scraping reviews for: Guerlain Habit Rouge Eau de Toilette ===
#
# === Scraping reviews for: Hermès Terre d'Hermès ===
#
# === Scraping reviews for: Hermès Un Jardin Sur Le Nil ===
#
# === Scraping reviews for: Hermès Un Jardin en Méditerranée ===
#
# === Scraping reviews for: Hermès Hiris ===
#
# === Scraping reviews for: Hermès Rouge Hermès ===
#
# === Scraping reviews for: Hermès 24 Faubourg Eau Delicate ===
#
# === Scraping reviews for: Hermès Caleche ===
#
# === Scraping reviews for: Hermès Caleche Eau Delicate ===
#
# === Scraping reviews for: Hermès Bel Ami ===
#
# === Scraping reviews for: Hermès Rocabar ===
#
# === Scraping reviews for: Hermès 24 Faubourg ===
#
# === Scraping reviews for: Rochas Femme Rochas ===
#
# === Scraping reviews for: Caron Tabac Blond ===
#
# === Scraping reviews for: Azzaro Visit for Women ===
#
# === Scraping reviews for: Angel Schlesser Angel Schlesser Femme ===
#
# === Scraping reviews for: Angel Schlesser Angel Schlesser Essential ===
#
# === Scraping reviews for: Givenchy Very Irresistible ===
#
# === Scraping reviews for: Givenchy Very Irresistible for men ===
#
# === Scraping reviews for: Givenchy Hot Couture ===
#
# === Scraping reviews for: Givenchy Ysatis ===
#
# === Scraping reviews for: Givenchy Givenchy pour Homme ===
#
# === Scraping reviews for: Givenchy Givenchy pour Homme Blue Label ===
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-7-2160162811> in <cell line: 0>()
#       3 for (perfume_name, perfume_url) in perfumes:
#       4     print(f"\n=== Scraping reviews for: {perfume_name} ===")
# ----> 5     df_reviews = scrape_reviews_to_df([perfume_url])
#       6     all_reviews_df = pd.concat([all_reviews_df, df_reviews], ignore_index=True)  # acumula
#       7
#
# <ipython-input-6-2373753322> in scrape_reviews_to_df(perfume_urls)
#      15         while page_url:
#      16             resp = scraper.get(page_url)
# ---> 17             resp.raise_for_status()
#      18             soup = BeautifulSoup(resp.text, 'html.parser')
#      19
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in raise_for_status(self)
#    1022
#    1023         if http_error_msg:
# -> 1024             raise HTTPError(http_error_msg, response=self)
#    1025
#    1026     def close(self):
#
# HTTPError: 429 Client Error: Too Many Requests for url: https://www.fragrantica.com.br/perfume/Givenchy/Givenchy-pour-Homme-Blue-Label-38.html

# %%
dados = " ".join(all_reviews_df["review_text"].astype(str))
dados

# %%
import re

chaves = [ "acessório", "acompanhamento", "alongamento", "amadeirado", "amo", "atitude", "autoamor", "autoestima",
    "autoimagem", "autocuidado", "autoconfiança", "autenticidade", "beleza", "blogueira", "bodysplash",
    "bolsa", "bolsas", "celebridades", "Chanel", "charme", "closet", "comprinha", "confiança", "conforto",
    "cosméticos", "cupom", "date", "dancinha", "descoberta", "destino", "Dior", "doce", "e-commerce",
    "elegância", "elegante", "emoção", "energia", "enjoativo", "estampas", "estilo", "exclusividade",
    "experiência", "expressão", "falsificado", "favorito", "felicidade", "feminilidade", "feminino",
    "Floral", "força", "Fraco", "frescura", "Frutado", "glamour", "Glow", "Gucci", "hidratação",
    "identidade", "impressiona", "importado", "influencer", "influenciadora", "instagram", "instagramável",
    "inspiração", "irresistivel", "irresistiveis", "Lancôme", "lembrança", "lifestyle", "lip oil", "look",
    "looks", "Longa", "lugar", "luxo", "maquiagem", "Marcante", "memória", "minimalismo", "moda",
    "momento", "Mugler", "necessaire", "Original", "oriental", "outfit", "passaporte", "pele",
    "personalidade", "poder", "popular", "praia", "prazer", "presente", "presentinho", "produto",
    "protagonismo", "promoção", "refrescante", "relaxamento", "resenha", "Réplica", "rosto", "rotina",
    "Sedutor", "sensação", "sensual", "sensualidade", "serum", "Sexy", "signos", "similar", "skincare",
    "social", "sofisticado", "stories", "suavidade", "tendência", "testador", "TikTok", "toque",
    "transformação", "vibe", "verão", "vício", "viagem", "vitrine", "wishlist", "YSL"]
chaves_upper = [k.upper() for k in chaves]

words = re.findall(r"\b\w+\b", dados)
words

# %% [markdown]
# ###CONTAGEM DAS PALAVRAS QUE ESCOLHEMOS

# %%
input_rdd = sc.parallelize(words, 3)

def map_to_keyword_count(word):
    w_up = word.upper()
    if w_up in chaves_upper:
        return (w_up, 1)
    else:
        return None

counts_rdd = (
    input_rdd
    .map(map_to_keyword_count)
    .filter(lambda kv: kv is not None)
    .reduceByKey(lambda a, b: a + b)
)

result = counts_rdd.collect()
print(result)

# %%
import nltk
from nltk.corpus import stopwords

nltk.download('stopwords')

stopwords_pt = set(stopwords.words('portuguese'))

palavras_filtradas = [p for p in words if p.lower() not in stopwords_pt]

print(palavras_filtradas)

# %% [markdown]
# ###CONTAGEM DE TODAS AS PALAVRAS

# %%
from pyspark import SparkContext

# Inicializa SparkContext
sc = SparkContext.getOrCreate()

# Paraleliza a lista de palavras em 3 partições
input_rdd = sc.parallelize(palavras_filtradas, 3)

# Função para mapear cada palavra para (palavra maiúscula, 1)
def map_to_count(word):
    return (word.upper(), 1)

# Conta as palavras
counts_rdd = (
    input_rdd
    .map(map_to_count)
    .reduceByKey(lambda a, b: a + b)
)

# Coleta resultado
result = counts_rdd.collect()

# Imprime resultado
print(result)

# %%
ordenado = sorted(result, key=lambda x: x[1], reverse=True)
print(ordenado)

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import random

# Função para gerar tons de rosa (R alto, G e B baixos/moderados)
def rosa_color_func(word, font_size, position, orientation, random_state=None, **kwargs):
    r = random.randint(200, 255)    # Vermelho forte
    g = random.randint(0, 100)      # Verde baixo
    b = random.randint(100, 180)    # Azul médio para lilás/rosa
    return f"rgb({r}, {g}, {b})"

frequencies = dict(ordenado)

wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(frequencies)

# Aplicar a função de cor rosa
plt.figure(figsize=(15, 7))
plt.imshow(wordcloud.recolor(color_func=rosa_color_func), interpolation='bilinear')
plt.axis("off")
plt.title("Nuvem de Todas as Palavras da Fragrantica")
plt.show()

# %% [markdown]
# ###REMOVENDO AS PALAVRAS INDESEJADAS

# %%
result_filtrado = [t for t in ordenado if t[0].upper() not in ["PQ","ALI","ETC","JA","UN","IR","PRECISO", "CONSEGUE","TB","VÃO","CREIO","MIM", "BEM", "PERFUME", "PERFUMES", "NOTAS", "FRAGRÂNCIA", "SINTO", "DIA", "ACHO", "ANOS", "TEMPO", "AROMA", "AINDA", "POIS", "NOTA", "POUCO", "FICA", "GOSTO", "VAI", "AQUI", "NADA", "PROJEÇÃO", "TUDO", "TÃO", "FRASCO", "FORTE", "TER", "SENTI", "ALGO", "LO", "VETIVER", "HORAS", "SENTIR", "USAR", "SAÍDA", "ASSIM", "VERDE", "TERRE", "LEMBRA", "AMARIGE", "AMO", "ACHEI", "PODE", "SEI", "TODO", "USO", "MENOS", "BASTANTE", "REALMENTE", "SIM", "HOJE", "PRIMEIRA", "TODOS", "PORQUE", "MEIO", "PIMENTA", "PERFUMARIA", "DÁ", "PORÉM", "DIFERENTE", "PARECE", "VIDA", "SEMPRE", "MARAVILHOSO", "SOBRE", "DESSE", "VEZ", "OBRA", "FAZ", "DIAS", "LEVE", "TERRA", "MULHER", "SENSAÇÃO", "QUALIDADE", "PESSOAS", "FORMA", "D", "VINTAGE", "OUTRO", "FRESCO", "NOITE", "FUNDO", "QUASE", "DEMAIS", "CLÁSSICO", "ATALCADO", "QUALQUER", "CASA", "TOQUE", "TANTO", "QUENTE", "CADA", "ALGUNS", "SUPER", "LOGO", "5", "COMPREI", "TALVEZ", "APENAS", "APESAR", "GOSTA", "ORGANZA", "FEMININO", "REMETE", "NUNCA", "MUITA", "TODA", "GENTE", "ONDE", "QUANTO", "COISA", "AGORA", "APÓS", "VERSÃO", "NELE", "FIXA", "PERFEITO", "10", "DIZER", "FIM", "EXTREMAMENTE", "ROSA", "ANTES", "VEZES", "OUTROS", "CONSIGO", "CEDRO", "TIPO", "MASCULINO", "ALGUMA", "BOA", "USADO", "EVOLUÇÃO", "SENDO", "ENTÃO", "MESMA", "BLIND", "AMOR", "VC", "NAO", "TUBEROSA", "JUNTO", "AGRADÁVEL", "GRANDE", "TODAS", "PERSONALIDADE", "USEI", "PRIMA", "JARDIM", "ÉPOCA", "PASSA", "MUNDO", "ALGUM", "VEM", "PRIMEIRO", "FINAL", "PROJETA", "DESSA", "ALGUMAS", "HORA", "VER", "BORRIFADA", "FIQUEI", "COMBINA", "DAR", "ASSINATURA", "FICOU", "HOMEM", "DIFÍCIL", "PENA", "MULHERES", "JASMIM", "LADO", "COURO", "CHEIRINHO", "OLFATO", "TRAZ", "CONFORTÁVEL", "FLOR", "OLFATIVA", "SABE", "VOU", "NARIZ", "QUER", "2", "PASSAR", "SIMPLESMENTE", "PRESENTE", "MUITOS", "MUITAS", "ABERTURA", "OCASIÕES", "GOSTAR", "AÍ", "NESSE", "PESSOA", "ABRE", "DELICIOSO", "ESTILO", "FALAR", "MOMENTO", "BASE", "ALÉM", "DEVE", "ÚNICO", "CONTA", "UNS", "COMPRAR", "CARA", "FICAR", "FRAGRÂNCIAS", "RESENHAS", "DESDE", "ACREDITO", "VIBE", "LEVEMENTE", "CORAÇÃO", "MOLHADA", "DEIXA", "MINUTOS", "VALE", "8", "SECO", "RS", "NENHUM", "EDT", "QUENTES", "TORNA", "NATURAL", "BORRIFADAS",
color_func(word, font_size, position, orientation, random_state=None, **kwargs):
    # Tons marrons pastéis suaves
    pastel_browns = [
        (210, 180, 140),  # Tan (bege amarronzado)
        (222, 184, 135),  # Burlywood (caramelo claro)
        (244, 164, 96),   # Sandy brown
        (205, 133, 63),   # Peru (marrom claro)
        (193, 154, 107),  # bege médio amarronzado
        (222, 210, 170),  # bege claro amarelado
        (230, 216, 181),  # bege pastel
    ]
    r, g, b = random.choice(pastel_browns)
    return f"rgb({r}, {g}, {b})"

frequencies = dict(result_filtrado)

wordcloud = WordCloud(width=800, height=400, background_color='#f5f0e6').generate_from_frequencies(frequencies)  # fundo bege claro

plt.figure(figsize=(15, 7))
plt.imshow(wordcloud.recolor(color_func=marrom_pastel_color_func), interpolation='bilinear')
plt.axis("off")
plt.title("Nuvem de Palavras da Fragrantica", color='#5C3A21', fontsize=15)
plt.show()

# %%
df_result = pd.DataFrame(result_filtrado, columns=["termo", "frequencia"])
print(df_result.sort_values(by="frequencia", ascending=False))

# %% [markdown]
# ##ANÁLISE DE SENTIMENTO

# %%
# !pip install unidecode
from unidecode import unidecode
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import random
from pyspark import SparkContext
import pandas as pd

# %%
# Inicializa o SparkContext
sc = SparkContext.getOrCreate()

palavras_negativas = ["ruim", "fraco", "enjoativo", "sintético", "desagradável", "agressivo", "dolorento",
                      "irritante", "exagerado", "nauseante", "incomodativo", "artificial", "fadigante",
                      "confuso", "infantil", "barato", "genérico", "ácido", "amargo", "ardido", "pesado",
                      "áspero", "velho", "frio", "morno", "rasteiro", "raso", "vazio", "comum", "repetitivo", "cansativo",
                      "estranho", "químico", "brusco", "apagado", "opaco", "irregular", "instável", "incômodo",
                      "desbotado", "desconfortável", "desinteressante", "desafinado", "desarmônico", "desproporcional",
                      "desgastado", "baixa fixação", "pouca projeção", "doce", "doce demais", "muito doce", "um pouco doce", "muito forte", "muito sintético",
                      "cheiro genérico", "cheiro barato", "cheiro enjoativo", "cheiro estranho", "cheiro desagradável", "cheiro químico",
                      "cheiro artificial", "cheiro infantil", "cheiro fraco", "cheiro apagado", "cheiro comum", "cheiro confuso", "cheiro incômodo",
                      "cheiro agressivo", "cheiro pesado", "muito fraco", "projeção baixa", "baixa fixação", "baixa projeção", "fixação baixa"]

# 2. Dados Coletados
# dados = " ".join(all_reviews_df["review_text"].astype(str))

# 3. Pré-processamento do texto
dados = unidecode(dados.lower())

# 4. Contagem com Spark
negativas_rdd = sc.parallelize(palavras_negativas)

def contar_ocorrencias(termo):
    return (termo, dados.count(termo))

result = negativas_rdd.map(contar_ocorrencias).filter(lambda x: x[1] > 0).collect()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import random

def marrom_pastel_color_func(word, font_size, position, orientation, random_state=None, **kwargs):

    pastel_browns = [
        (210, 180, 140),
        (222, 184, 135),
        (244, 164, 96),
        (205, 133, 63),
        (193, 154, 107),
        (222, 210, 170),
        (230, 216, 181),
        ]
    r, g, b = random.choice(pastel_browns)
    return f"rgb({r}, {g}, {b})"

frequencies = dict(result)

wordcloud = WordCloud(width=800, height=400, background_color='#f5f0e6').generate_from_frequencies(frequencies)

plt.figure(figsize=(15, 7))
plt.imshow(wordcloud.recolor(color_func=marrom_pastel_color_func), interpolation='bilinear')
plt.axis("off")
plt.title("Nuvem Análise de Sentimentos", color='#5C3A21', fontsize=15)
plt.show()

# %%
# Mostrar a tabela dos termos negativos encontrados
df_result = pd.DataFrame(result, columns=["termo", "frequencia"])
print(df_result.sort_values(by="frequencia", ascending=False))
